# %%
import pandas as pd

# %%
pd.read_excel('./Data/GDP_and_Major_Industrial_Sectors_of_Economy_Dataset.xls')
# Out:
#    Financial Year  Gross Domestic Product (in Rs. Cr) at 2004-05 Prices  \
# 0         1951-52                                       2.861469e+05
# 1         1952-53                                       2.942671e+05
# 2         1953-54                                       3.121774e+05
# 3         1954-55                                       3.254307e+05
# 4         1955-56                                       3.337663e+05
# 5         1956-57                                       3.527658e+05
# 6         1957-58                                       3.485002e+05
# 7         1958-59                                       3.749481e+05
# 8         1959-60                                       3.831532e+05
# 9         1960-61                                       4.102795e+05
# 10        1961-62                                       4.230110e+05
# 11        1962-63                                       4.319597e+05
# 12        1963-64                                       4.538290e+05
# ...
