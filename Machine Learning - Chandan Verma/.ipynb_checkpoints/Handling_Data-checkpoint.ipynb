# %%
import pandas as pd

# %%
data = pd.read_csv('./Titanic_Data.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'].isnull().sum()
# Out:
# 177

# %%
data.loc[ data['Age'].isnull() & data['Cabin'].isnull(), :]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# ...

# %%
X = data.copy()
Ym = data.dropna(how='any')

# %%
'Shape of X : {}, Shape of Xm : {}'.format(X.shape, Ym.shape)
# Out:
# 'Shape of X : (891, 12), Shape of Xm : (183, 12)'

# %%
Ym = data.dropna(how='all', thresh=1)
'Shape of X : {}, Shape of Xm : {}'.format(X.shape, Ym.shape)
# Out:
# 'Shape of X : (891, 12), Shape of Xm : (891, 12)'

# %%
# data.dropna(inplace=True)

# %%
data.fillna(0, inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.groupby(['Sex']).mean().T
# Out:
# Sex              female        male
# PassengerId  431.028662  454.147314
# Survived       0.742038    0.188908
# Pclass         2.159236    2.389948
# Age           23.203822   24.123345
# SibSp          0.694268    0.429809
# Parch          0.649682    0.235702
# Fare          44.479818   25.523893

# %%
data.groupby(['Survived']).mean().T
# Out:
# Survived              0           1
# PassengerId  447.016393  444.368421
# Pclass         2.531876    1.950292
# Age           23.653005   24.034123
# SibSp          0.553734    0.473684
# Parch          0.329690    0.464912
# Fare          22.117887   48.395408

# %%
data.groupby(['Sex', 'Survived']).mean().T
# Out:
# Sex              female                    male
# Survived              0           1           0           1
# PassengerId  434.851852  429.699571  449.121795  475.724771
# Pclass         2.851852    1.918455    2.476496    2.018349
# Age           19.790123   24.390558   24.321581   23.272202
# SibSp          1.209877    0.515021    0.440171    0.385321
# Parch          1.037037    0.515021    0.207265    0.357798
# Fare          23.024385   51.938573   21.960993   40.821484

# %% [markdown]
# # How to Handle Categorical Data
