# %%
import pandas as pd

# %%
pd.read_csv('./Data/Gross_Domestic_Product_All_India_and_Madhya_Pradesh.csv')
# Out:
#           Year  Comparative Figures (Crore Rs.) All-India At Current Prices  \
# 0     2004-05                                             2971464
# 1     2005-06                                             3390503
# 2      2006-07                                            3953276
# 3      2007-08                                            4582086
# 4      2008-09                                            5303567
# 5      2009-10                                            6108903
# 6      2010-11                                            7248860
# 7  2011-12 (P)                                            8391691
# 8  2012-13 (Q)                                            9388876
# 9  2012-13 (A)                                           10539605
#
#    Comparative Figures (Crore Rs.) All-India At Constant Prices  \
# 0                                            2971464
# 1                                            3253073
# 2                                            3564364
# ...
